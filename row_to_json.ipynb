# %%
# row_to_json.py
import pandas as pd
import json
from datetime import datetime

def extract_row_as_json(csv_path, timestamp_str, output_file=None):
    """
    Extract a specific row from the raw dataset and convert it to JSON format.
    
    Args:
        csv_path: Path to the CSV file
        timestamp_str: Timestamp string to find (e.g., "2014-11-15 06:30:00")
        output_file: Optional path to save JSON file
    
    Returns:
        dict: Row data as dictionary/JSON
    """
    # Load the raw dataset
    df = pd.read_csv(csv_path, parse_dates=["date_time"])
    
    # Find the specific row
    target_ts = pd.to_datetime(timestamp_str)
    row = df.loc[df["date_time"] == target_ts]
    
    if row.empty:
        # Try to find nearest row within 5 minutes
        nearest_idx = (df["date_time"] - target_ts).abs().argsort()[:1]
        row = df.iloc[nearest_idx]
        actual_ts = row.iloc[0]["date_time"]
        time_diff = abs(actual_ts - target_ts)
        if time_diff > pd.Timedelta(minutes=5):
            raise ValueError(f"No row found within 5 minutes of {timestamp_str}")
        print(f"Using nearest row at {actual_ts} (diff: {time_diff})")
    
    # Convert row to dictionary
    row_dict = row.iloc[0].to_dict()
    
    # Convert timestamps to string format for JSON serialization
    for key, value in row_dict.items():
        if isinstance(value, pd.Timestamp):
            row_dict[key] = value.strftime("%Y-%m-%d %H:%M:%S")
        elif pd.isna(value):
            row_dict[key] = None
    
    # Save to file if requested
    if output_file:
        with open(output_file, 'w') as f:
            json.dump(row_dict, f, indent=2)
        print(f"Row data saved to {output_file}")
    
    return row_dict

def show_sample_rows(csv_path, n=5):
    """Show first n rows to help select a timestamp"""
    df = pd.read_csv(csv_path, parse_dates=["date_time"])
    print(f"Dataset shape: {df.shape}")
    print(f"Date range: {df['date_time'].min()} to {df['date_time'].max()}")
    print(f"\nFirst {n} rows:")
    print(df[['date_time'] + [col for col in df.columns if col != 'date_time'][:5]].head(n))
    print(f"\nColumn names: {list(df.columns)}")

# Example usage
if __name__ == "__main__":
    csv_path = "wt84_with_alarms.csv"  # Update with your CSV path
    
    # Show sample data to help choose a timestamp
    show_sample_rows(csv_path)
    
    # Extract a specific row (update timestamp as needed)
    try:
        row_json = extract_row_as_json(csv_path, "2012-04-06 01:05:00", "sample_row.json")
        print("\nExtracted row JSON:")
        print(json.dumps(row_json, indent=2))
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Dataset shape: (210698, 319)
# Date range: 2012-01-01 01:05:00 to 2014-12-08 06:20:00
#
# First 5 rows:
#             date_time  turbine_id  wgdc_avg_TriGri_PhV_phsA  \
# 0 2012-01-01 01:05:00          84                   392.239
# 1 2012-01-01 01:10:00          84                   392.714
# 2 2012-01-01 01:15:00          84                   393.002
# 3 2012-01-01 01:20:00          84                   393.793
# 4 2012-01-01 01:25:00          84                   394.844
#
#    wgdc_avg_TriGri_PhV_phsB  wgdc_avg_TriGri_PhV_phsC  wgdc_avg_TriGri_PhV
# 0                   390.227                   392.632              391.241
# 1                   390.730                   393.000              391.737
# 2                   391.001                   393.061              392.002
# 3                   391.750                   393.778              392.797
# 4                   392.852                   394.829              393.850
#
# Column names: ['turbine_id', 'date_time', 'wgdc_avg_TriGri_PhV_phsA', 'wgdc_avg_TriGri_PhV_phsB', 'wgdc_avg_TriGri_PhV_phsC', 'wgdc_avg_TriGri_PhV', 'wgdc_avg_TriGri_A_phsA', 'wgdc_avg_TriGri_A_phsB', 'wgdc_avg_TriGri_A_phsC', 'wgdc_avg_TriGri_A', 'wgdc_avg_TriGri_PF', 'wgdc_avg_TriGri_Hz', 'wgdc_avg_TriGri_PwrAt', 'wgdc_avg_TriGri_PwrReact', 'wgdc_avg_GdcTmp_TrfGn', 'wgdc_avg_LoVTmp', 'wgdc_max_TriGri_PhV_phsA', 'wgdc_max_TriGri_PhV_phsB', 'wgdc_max_TriGri_PhV_phsC', 'wgdc_max_TriGri_PhV', 'wgdc_max_TriGri_A_phsA', 'wgdc_max_TriGri_A_phsB', 'wgdc_max_TriGri_A_phsC', 'wgdc_max_TriGri_A', 'wgdc_max_TriGri_PF', 'wgdc_max_TriGri_Hz', 'wgdc_max_TriGri_PwrAt', 'wgdc_max_TriGri_PwrReact', 'wgdc_max_GdcTmp_TrfGn', 'wgdc_max_LoVTmp', 'wgdc_min_TriGri_PhV_phsA', 'wgdc_min_TriGri_PhV_phsB', 'wgdc_min_TriGri_PhV_phsC', 'wgdc_min_TriGri_PhV', 'wgdc_min_TriGri_A_phsA', 'wgdc_min_TriGri_A_phsB', 'wgdc_min_TriGri_A_phsC', 'wgdc_min_TriGri_A', 'wgdc_min_TriGri_PF', 'wgdc_min_TriGri_Hz', 'wgdc_min_TriGri_PwrAt', 'wgdc_min_TriGri_PwrReact', 'wgdc_min_GdcTmp_TrfGn', 'wgdc_min_LoVTmp', 'wgdc_sdv_TriGri_PhV_phsA', 'wgdc_sdv_TriGri_PhV_phsB', 'wgdc_sdv_TriGri_PhV_phsC', 'wgdc_sdv_TriGri_PhV', 'wgdc_sdv_TriGri_A_phsA', 'wgdc_sdv_TriGri_A_phsB', 'wgdc_sdv_TriGri_A_phsC', 'wgdc_sdv_TriGri_A', 'wgdc_sdv_TriGri_PF', 'wgdc_sdv_TriGri_Hz', 'wgdc_sdv_TriGri_PwrAt', 'wgdc_sdv_TriGri_PwrReact', 'wgdc_sdv_GdcTmp_TrfGn', 'wgdc_sdv_LoVTmp', 'wtrm_avg_TrmTmp_Brg1', 'wtrm_avg_TrmTmp_Brg2', 'wtrm_avg_TrmTmp_GbxOil', 'wtrm_avg_TrmTmp_GbxBrg151', 'wtrm_avg_TrmTmp_GbxBrg451', 'wtrm_avg_TrmTmp_Gbx', 'wtrm_avg_TrmTmp_GbxBrg450', 'wtrm_avg_TrmTmp_GbxBrg152', 'wtrm_avg_TrmTmp_GbxBrg452', 'wtrm_avg_TrmTmp_GbxClWtBkw', 'wtrm_avg_TrmTmp_GbxClWtFrw', 'wtrm_avg_TrmTmp_GnClWtBkw', 'wtrm_avg_TrmTmp_GnClWtFrw', 'wtrm_avg_TrmTmp_GnBrgDE', 'wtrm_avg_TrmTmp_GnBrgNDE', 'wtrm_avg_Brg_OilPres', 'wtrm_avg_Gbx_OilPres', 'wtrm_avg_Brg_OilPresIn', 'wtrm_max_TrmTmp_Brg1', 'wtrm_max_TrmTmp_Brg2', 'wtrm_max_TrmTmp_GbxOil', 'wtrm_max_TrmTmp_GbxBrg151', 'wtrm_max_TrmTmp_GbxBrg451', 'wtrm_max_TrmTmp_Gbx', 'wtrm_max_TrmTmp_GbxBrg450', 'wtrm_max_TrmTmp_GbxBrg152', 'wtrm_max_TrmTmp_GbxBrg452', 'wtrm_max_TrmTmp_GbxClWtBkw', 'wtrm_max_TrmTmp_GbxClWtFrw', 'wtrm_max_TrmTmp_GnClWtBkw', 'wtrm_max_TrmTmp_GnClWtFrw', 'wtrm_max_TrmTmp_GnBrgDE', 'wtrm_max_TrmTmp_GnBrgNDE', 'wtrm_max_Brg_OilPres', 'wtrm_max_Gbx_OilPres', 'wtrm_max_Brg_OilPresIn', 'wtrm_min_TrmTmp_Brg1', 'wtrm_min_TrmTmp_Brg2', 'wtrm_min_TrmTmp_GbxOil', 'wtrm_min_TrmTmp_GbxBrg151', 'wtrm_min_TrmTmp_GbxBrg451', 'wtrm_min_TrmTmp_Gbx', 'wtrm_min_TrmTmp_GbxBrg450', 'wtrm_min_TrmTmp_GbxBrg152', 'wtrm_min_TrmTmp_GbxBrg452', 'wtrm_min_TrmTmp_GbxClWtBkw', 'wtrm_min_TrmTmp_GbxClWtFrw', 'wtrm_min_TrmTmp_GnClWtBkw', 'wtrm_min_TrmTmp_GnClWtFrw', 'wtrm_min_TrmTmp_GnBrgDE', 'wtrm_min_TrmTmp_GnBrgNDE', 'wtrm_min_Brg_OilPres', 'wtrm_min_Gbx_OilPres', 'wtrm_min_Brg_OilPresIn', 'wtrm_sdv_TrmTmp_Brg1', 'wtrm_sdv_TrmTmp_Brg2', 'wtrm_sdv_TrmTmp_GbxOil', 'wtrm_sdv_TrmTmp_GbxBrg151', 'wtrm_sdv_TrmTmp_GbxBrg451', 'wtrm_sdv_TrmTmp_Gbx', 'wtrm_sdv_TrmTmp_GbxBrg450', 'wtrm_sdv_TrmTmp_GbxBrg152', 'wtrm_sdv_TrmTmp_GbxBrg452', 'wtrm_sdv_TrmTmp_GbxClWtBkw', 'wtrm_sdv_TrmTmp_GbxClWtFrw', 'wtrm_sdv_TrmTmp_GnClWtBkw', 'wtrm_sdv_TrmTmp_GnClWtFrw', 'wtrm_sdv_TrmTmp_GnBrgDE', 'wtrm_sdv_TrmTmp_GnBrgNDE', 'wtrm_sdv_Brg_OilPres', 'wtrm_sdv_Gbx_OilPres', 'wtrm_sdv_Brg_OilPresIn', 'wnac_avg_NacTmp', 'wnac_avg_WVaneDir2', 'wnac_avg_WSpd2', 'wnac_avg_Dir', 'wnac_avg_WVaneDir1', 'wnac_avg_WSpd1', 'wnac_avg_ExlTmp', 'wnac_avg_Wdir1', 'wnac_avg_Wdir2', 'wnac_max_NacTmp', 'wnac_max_WVaneDir2', 'wnac_max_WSpd2', 'wnac_max_Dir', 'wnac_max_WVaneDir1', 'wnac_max_WSpd1', 'wnac_max_ExlTmp', 'wnac_max_Wdir1', 'wnac_max_Wdir2', 'wnac_min_NacTmp', 'wnac_min_WVaneDir2', 'wnac_min_WSpd2', 'wnac_min_Dir', 'wnac_min_WVaneDir1', 'wnac_min_WSpd1', 'wnac_min_ExlTmp', 'wnac_min_Wdir1', 'wnac_min_Wdir2', 'wnac_sdv_NacTmp', 'wnac_sdv_WVaneDir2', 'wnac_sdv_WSpd2', 'wnac_sdv_Dir', 'wnac_sdv_WVaneDir1', 'wnac_s ...
# Row data saved to sample_row.json
#
# Extracted row JSON:
# {
#   "turbine_id": 84,
#   "date_time": "2012-04-06 01:05:00",
#   "wgdc_avg_TriGri_PhV_phsA": 395.496,
#   "wgdc_avg_TriGri_PhV_phsB": 394.828,
#   "wgdc_avg_TriGri_PhV_phsC": 395.742,
#   "wgdc_avg_TriGri_PhV": 394.831,
#   "wgdc_avg_TriGri_A_phsA": 839.119,
#   "wgdc_avg_TriGri_A_phsB": 798.492,
#   "wgdc_avg_TriGri_A_phsC": 816.854,
#   "wgdc_avg_TriGri_A": 818.168,
#   "wgdc_avg_TriGri_PF": -0.991,
#   "wgdc_avg_TriGri_Hz": 49.993,
#   "wgdc_avg_TriGri_PwrAt": 971.417,
#   "wgdc_avg_TriGri_PwrReact": 15.7051,
#   "wgdc_avg_GdcTmp_TrfGn": 57.3,
#   "wgdc_avg_LoVTmp": 31.5,
#   "wgdc_max_TriGri_PhV_phsA": 396.0,
#   "wgdc_max_TriGri_PhV_phsB": 395.0,
#   "wgdc_max_TriGri_PhV_phsC": 396.0,
#   "wgdc_max_TriGri_PhV": 395.0,
#   "wgdc_max_TriGri_A_phsA": 998.0,
#   "wgdc_max_TriGri_A_phsB": 962.0,
#   "wgdc_max_TriGri_A_phsC": 974.0,
#   "wgdc_max_TriGri_A": 976,
#   "wgdc_max_TriGri_PF": -0.991,
#   "wgdc_max_TriGri_Hz": 49.993,
#   "wgdc_max_TriGri_PwrAt": 1150.59,
#   "wgdc_max_TriGri_PwrReact": 30.726,
#   "wgdc_max_GdcTmp_TrfGn": 57.3,
#   "wgdc_max_LoVTmp": 31.5,
#   "wgdc_min_TriGri_PhV_phsA": 395.0,
#   "wgdc_min_TriGri_PhV_phsB": 394.0,
#   "wgdc_min_TriGri_PhV_phsC": 395.0,
#   "wgdc_min_TriGri_PhV": 394.0,
#   "wgdc_min_TriGri_A_phsA": 745.0,
#   "wgdc_min_TriGri_A_phsB": 705.0,
#   "wgdc_min_TriGri_A_phsC": 723.0,
#   "wgdc_min_TriGri_A": 724,
#   "wgdc_min_TriGri_PF": -0.991,
#   "wgdc_min_TriGri_Hz": 49.993,
#   "wgdc_min_TriGri_PwrAt": 870.47,
#   "wgdc_min_TriGri_PwrReact": -1.33,
#   "wgdc_min_GdcTmp_TrfGn": 57.3,
#   "wgdc_min_LoVTmp": 31.5,
#   "wgdc_sdv_TriGri_PhV_phsA": 0.499986,
#   "wgdc_sdv_TriGri_PhV_phsB": 0.377074,
#   "wgdc_sdv_TriGri_PhV_phsC": 0.437368,
#   "wgdc_sdv_TriGri_PhV": 0.375031,
#   "wgdc_sdv_TriGri_A_phsA": 53.1171,
#   "wgdc_sdv_TriGri_A_phsB": 52.2971,
#   "wgdc_sdv_TriGri_A_phsC": 52.2349,
#   "wgdc_sdv_TriGri_A": 52.5552,
#   "wgdc_sdv_TriGri_PF": 0.0,
#   "wgdc_sdv_TriGri_Hz": 0.0,
#   "wgdc_sdv_TriGri_PwrAt": 62.1866,
#   "wgdc_sdv_TriGri_PwrReact": 6.24206,
#   "wgdc_sdv_GdcTmp_TrfGn": 0.0,
#   "wgdc_sdv_LoVTmp": 0.0,
#   "wtrm_avg_TrmTmp_Brg1": 42.9,
#   "wtrm_avg_TrmTmp_Brg2": 43.5,
#   "wtrm_avg_TrmTmp_GbxOil": 52.2,
#   "wtrm_avg_TrmTmp_GbxBrg151": 55.6,
#   "wtrm_avg_TrmTmp_GbxBrg451": 51.2,
#   "wtrm_avg_TrmTmp_Gbx": 70.4,
#   "wtrm_avg_TrmTmp_GbxBrg450": 51.6,
#   "wtrm_avg_TrmTmp_GbxBrg152": 65.1,
#   "wtrm_avg_TrmTmp_GbxBrg452": 46.3,
#   "wtrm_avg_TrmTmp_GbxClWtBkw": 35.1,
#   "wtrm_avg_TrmTmp_GbxClWtFrw": 39.4,
#   "wtrm_avg_TrmTmp_GnClWtBkw": 28.6,
#   "wtrm_avg_TrmTmp_GnClWtFrw": 33.7,
#   "wtrm_avg_TrmTmp_GnBrgDE": 41.9,
#   "wtrm_avg_TrmTmp_GnBrgNDE": 39.6,
#   "wtrm_avg_Brg_OilPres": 0.75,
#   "wtrm_avg_Gbx_OilPres": 2.1621,
#   "wtrm_avg_Brg_OilPresIn": 0.19,
#   "wtrm_max_TrmTmp_Brg1": 42.9,
#   "wtrm_max_TrmTmp_Brg2": 43.5,
#   "wtrm_max_TrmTmp_GbxOil": 52.2,
#   "wtrm_max_TrmTmp_GbxBrg151": 55.6,
#   "wtrm_max_TrmTmp_GbxBrg451": 51.2,
#   "wtrm_max_TrmTmp_Gbx": 70.4,
#   "wtrm_max_TrmTmp_GbxBrg450": 51.6,
#   "wtrm_max_TrmTmp_GbxBrg152": 65.1,
#   "wtrm_max_TrmTmp_GbxBrg452": 46.3,
#   "wtrm_max_TrmTmp_GbxClWtBkw": 35.1,
#   "wtrm_max_TrmTmp_GbxClWtFrw": 39.4,
#   "wtrm_max_TrmTmp_GnClWtBkw": 28.6,
#   "wtrm_max_TrmTmp_GnClWtFrw": 33.7,
#   "wtrm_max_TrmTmp_GnBrgDE": 41.9,
#   "wtrm_max_TrmTmp_GnBrgNDE": 39.6,
#   "wtrm_max_Brg_OilPres": 0.75,
#   "wtrm_max_Gbx_OilPres": 2.26,
#   "wtrm_max_Brg_OilPresIn": 0.19,
#   "wtrm_min_TrmTmp_Brg1": 42.9,
#   "wtrm_min_TrmTmp_Brg2": 43.5,
#   "wtrm_min_TrmTmp_GbxOil": 52.2,
#   "wtrm_min_TrmTmp_GbxBrg151": 55.6,
#   "wtrm_min_TrmTmp_GbxBrg451": 51.2,
#   "wtrm_min_TrmTmp_Gbx": 70.4,
#   "wtrm_min_TrmTmp_GbxBrg450": 51.6,
#   "wtrm_min_TrmTmp_GbxBrg152": 65.1,
#   "wtrm_min_TrmTmp_GbxBrg452": 46.3,
#   "wtrm_min_TrmTmp_GbxClWtBkw": 35.1,
#   "wtrm_min_TrmTmp_GbxClWtFrw": 39.4,
#   "wtrm_min_TrmTmp_GnClWtBkw": 28.6,
#   "wtrm_min_TrmTmp_GnClWtFrw": 33.7,
#   "wtrm_min_TrmTmp_GnBrgDE": 41.9,
#   "wtrm_min_TrmTmp_GnBrgNDE": 39.6,
#   "wtrm_min_Brg_OilPres": 0.75,
#   "wtrm_min_Gbx_OilPres": 2.09,
#   "wtrm_min_Brg_OilPresIn": 0.19,
#   "wtrm_sdv_TrmTmp_Brg1": 0.0,
#   "wtrm_sdv_TrmTmp_Brg2": 0.0,
#   "wtrm_sdv_TrmTmp_GbxOil": 0.0,
#   "wtrm_sdv_TrmTmp_GbxBrg151": 0.0,
#   "wtrm_sdv_TrmTmp_GbxBrg451": 0.0,
#   "wtrm_sdv_TrmTmp_Gbx": 0.0,
#   "wtrm_sdv_TrmTmp_GbxBrg450": 0.0,
#   "wtrm_sdv_TrmTmp_GbxBrg152": 0.0,
#   "wtrm_sdv_TrmTmp_GbxBrg452": 0.0,
#   "wtrm_sdv_TrmTmp_GbxClWtBkw": 0.0,
#   "wtrm_sdv_TrmTmp_GbxClWtFrw": 0.0,
#   "wtrm_sdv_TrmTmp_GnClWtBkw": 0.0,
#   "wtrm_sdv_TrmTmp_GnClWtFrw": 0.0,
#   "wtrm_sdv_TrmTmp_GnBrgDE": 0.0,
#   "wtrm_sdv_TrmTmp_GnBrgNDE": 0.0,
#   "wtrm_sdv_Brg_OilPres": 0.0,
#   "wtrm_sdv_Gbx_OilPres": 0.0305144,
#   "wtrm_sdv_Brg_OilPresIn": 0.0,
#   "wnac_avg_NacTmp": 27.7,
#   "wnac_avg_WVaneDir2": 279.453,
#   "wnac_avg_WSpd2": 8.46392,
#   "wnac_avg_Dir": 83.6,
#   "wnac_avg_WVaneDir1": 306.94,
#   "wnac_avg_WSpd1": 8.28507,
#   "wnac_avg_ExlTmp": 9.73245,
#   "wnac_avg_Wdir1": 80.5133,
#   "wnac_avg_Wdir2": 76.0743,
#   "wnac_max_NacTmp": 27.7,
#   "wnac_max_WVaneDir2": 359.9,
#   "wnac_max_WSpd2": 10.34,
#   "wnac_max_Dir": 83.6,
#   "wnac_max_WVaneDir1": 359,
#   "wnac_max_WSpd1": 9.8,
#   "wnac_max_ExlTmp": 9.8,
#   "wnac_max_Wdir1": 93.6,
#   "wnac_max_Wdir2": 118.8,
#   "wnac_min_NacTmp": 27.7,
#   "wnac_min_WVaneDir2": 0.0,
#   "wnac_min_WSpd2": 6.71,
#   "wnac_min_Dir": 83.6,
#   "wnac_min_WVaneDir1": 0,
#   "wnac_min_WSpd1": 6.9,
#   "wnac_min_ExlTmp": 9.7,
#   "wnac_min_Wdir1": 75.6,
#   "wnac_min_Wdir2": 45.9,
#   "wnac_sdv_NacTmp": 0.0,
#   "wnac_sdv_WVaneDir2": 137.498,
#   "wnac_sdv_WSpd2": 0.601102,
#   "wnac_sdv_Dir": 0.0,
#   "wnac_sdv_WVaneDir1": 122.659,
#   "wnac_sdv_WSpd1": 0.595716,
#   "wnac_sdv_ExlTmp": 0.0468195,
#   "wnac_sdv_Wdir1": 2.76214,
#   "wnac_sdv_Wdir2": 9.88937,
#   "wgen_avg_GnTmp_phsA": 56.484,
#   "wgen_avg_GnTmp_phsB": 56.2977,
#   "wgen_avg_GnTmp_phsC": 56.215,
#   "wgen_avg_RtrSpd_IGR": 13.5027,
#   "wgen_avg_Spd": 1073.65,
#   "wgen_avg_RtrSpd_WP2035": 13.5058,
#   "wgen_max_GnTmp_phsA": 57.3,
#   "wgen_max_GnTmp_phsB": 55.6,
#   "wgen_max_GnTmp_phsC": 58.9,
#   "wgen_max_RtrSpd_IGR": 14.11,
#   "wgen_max_Spd": 1121.58,
#   "wgen_max_RtrSpd_WP2035": 14.33,
#   "wgen_min_GnTmp_phsA": 55.6,
#   "wgen_min_GnTmp_phsB": 57.0,
#   "wgen_min_GnTmp_phsC": 53.4,
#   "wgen_min_RtrSpd_IGR": 13.15,
#   "wgen_min_Spd": 1046.32,
#   "wgen_min_RtrSpd_WP2035": 12.93,
#   "wgen_sdv_GnTmp_phsA": 0.634779,
#   "wgen_sdv_GnTmp_phsB": 0.561593,
#   "wgen_sdv_GnTmp_phsC": 1.69685,
#   "wgen_sdv_RtrSpd_IGR": 0.254032,
#   "wgen_sdv_Spd": 20.1985,
#   "wgen_sdv_RtrSpd_WP2035": 0.294119,
#   "wtow_avg_PwrPnlTmp": 17.8,
#   "wtow_max_PwrPnlTmp": 17.8,
#   "wtow_min_PwrPnlTmp": 17.8,
#   "wtow_sdv_PwrPnlTmp": 0.0,
#   "wtur_avg_PwrRedCau": 0.0,
#   "wtur_avg_PwrRedSp": 0,
#   "wtur_avg_ExtPwrSpUtil": 2500.0,
#   "wtur_avg_PwrRedNoi": 0,
#   "wtur_avg_ExtPwrReactSp": 24.7763,
#   "wtur_max_PwrRedCau": 0,
#   "wtur_max_PwrRedSp": 0,
#   "wtur_max_ExtPwrSpUtil": 2500.0,
#   "wtur_max_PwrRedNoi": 0,
#   "wtur_max_ExtPwrReactSp": 39.148,
#   "wtur_min_PwrRedCau": 0,
#   "wtur_min_PwrRedSp": 0,
#   "wtur_min_ExtPwrSpUtil": 2500.0,
#   "wtur_min_PwrRedNoi": 0,
#   "wtur_min_ExtPwrReactSp": 6.444,
#   "wtur_sdv_PwrRedCau": 0.0,
#   "wtur_sdv_PwrRedSp": 0,
#   "wtur_sdv_ExtPwrSpUtil": 0.0,
#   "wtur_sdv_PwrRedNoi": 0,
#   "wtur_sdv_ExtPwrReactSp": 6.10921,
#   "wrot_avg_V_ValBl1": 90.1022,
#   "wrot_avg_TmpCpt_Bl1": 32.1291,
#   "wrot_avg_A_ValBl1": 0.00361056,
#   "wrot_avg_TmpHtSinkPco_Bl1": 32.5935,
#   "wrot_avg_RotSt_Bl1_PDU": 42.5727,
#   "wrot_avg_TmpPwrSply_ValBl1": 33.1,
#   "wrot_avg_V_ValBl2": 88.9149,
#   "wrot_avg_TmpCpt_Bl2": 32.2289,
#   "wrot_avg_A_ValBl2": 0.98533,
#   "wrot_avg_TmpHtSinkPco_Bl2": 32.6721,
#   "wrot_avg_TmpPDU_ValBl2": 45.0122,
#   "wrot_avg_TmpPwrSply_ValBl2": 33.2984,
#   "wrot_avg_V_ValBl3": 88.7853,
#   "wrot_avg_TmpCpt_Bl3": 32.3,
#   "wrot_avg_A_ValBl3": 0.592925,
#   "wrot_avg_TmpHtSinkPco_Bl3": 32.9018,
#   "wrot_avg_TmpPDU_ValBl3": 39.1488,
#   "wrot_avg_TmpPwrSply_ValBl3": 33.1,
#   "wrot_max_V_ValBl1": 90.3,
#   "wrot_max_TmpCpt_Bl1": 32.3,
#   "wrot_max_A_ValBl1": 4.3,
#   "wrot_max_TmpHtSinkPco_Bl1": 32.6,
#   "wrot_max_RotSt_Bl1_PDU": 42.6,
#   "wrot_max_TmpPwrSply_ValBl1": 33.1,
#   "wrot_max_V_ValBl2": 89.1,
#   "wrot_max_TmpCpt_Bl2": 32.3,
#   "wrot_max_A_ValBl2": 2.3,
#   "wrot_max_TmpHtSinkPco_Bl2": 32.7,
#   "wrot_max_TmpPDU_ValBl2": 45.1,
#   "wrot_max_TmpPwrSply_ValBl2": 33.3,
#   "wrot_max_V_ValBl3": 89.0,
#   "wrot_max_TmpCpt_Bl3": 32.4,
#   "wrot_max_A_ValBl3": 4.5,
#   "wrot_max_TmpHtSinkPco_Bl3": 33.0,
#   "wrot_max_TmpPDU_ValBl3": 39.5,
#   "wrot_max_TmpPwrSply_ValBl3": 33.1,
#   "wrot_min_V_ValBl1": 89.9,
#   "wrot_min_TmpCpt_Bl1": 32.1,
#   "wrot_min_A_ValBl1": -2.2,
#   "wrot_min_TmpHtSinkPco_Bl1": 32.5,
#   "wrot_min_RotSt_Bl1_PDU": 42.4,
#   "wrot_min_TmpPwrSply_ValBl1": 33.1,
#   "wrot_min_V_ValBl2": 88.6,
#   "wrot_min_TmpCpt_Bl2": 32.2,
#   "wrot_min_A_ValBl2": -0.3,
#   "wrot_min_TmpHtSinkPco_Bl2": 32.6,
#   "wrot_min_TmpPDU_ValBl2": 44.8,
#   "wrot_min_TmpPwrSply_ValBl2": 33.2,
#   "wrot_min_V_ValBl3": 88.4,
#   "wrot_min_TmpCpt_Bl3": 32.2,
#   "wrot_min_A_ValBl3": -1.5,
#   "wrot_min_TmpHtSinkPco_Bl3": 32.8,
#   "wrot_min_TmpPDU_ValBl3": 39.0,
#   "wrot_min_TmpPwrSply_ValBl3": 33.1,
#   "wrot_sdv_V_ValBl1": 0.0791457,
#   "wrot_sdv_TmpCpt_Bl1": 0.0699761,
#   "wrot_sdv_A_ValBl1": 0.638553,
#   "wrot_sdv_TmpHtSinkPco_Bl1": 0.0246996,
#   "wrot_sdv_RotSt_Bl1_PDU": 0.0453781,
#   "wrot_sdv_TmpPwrSply_ValBl1": 0.0,
#   "wrot_sdv_V_ValBl2": 0.0817248,
#   "wrot_sdv_TmpCpt_Bl2": 0.0453444,
#   "wrot_sdv_A_ValBl2": 0.315359,
#   "wrot_sdv_TmpHtSinkPco_Bl2": 0.0448327,
#   "wrot_sdv_TmpPDU_ValBl2": 0.0776655,
#   "wrot_sdv_TmpPwrSply_ValBl2": 0.0125756,
#   "wrot_sdv_V_ValBl3": 0.095303,
#   "wrot_sdv_TmpCpt_Bl3": 0.00421903,
#   "wrot_sdv_A_ValBl3": 0.744451,
#   "wrot_sdv_TmpHtSinkPco_Bl3": 0.0187013,
#   "wrot_sdv_TmpPDU_ValBl3": 0.114967,
#   "wrot_sdv_TmpPwrSply_ValBl3": 0.0,
#   "wcnv_avg_InvTmp_ClWtrFwd": 46.0129,
#   "wcnv_avg_InvTmp_ClWtrRet": 47.6358,
#   "wcnv_avg_HtSnkTmp": 55.4819,
#   "wcnv_avg_IGBTTmp": 0,
#   "wcnv_max_InvTmp_ClWtrFwd": 49.2,
#   "wcnv_max_InvTmp_ClWtrRet": 50.3,
#   "wcnv_max_HtSnkTmp": 57.5,
#   "wcnv_max_IGBTTmp": 0,
#   "wcnv_min_InvTmp_ClWtrFwd": 37.8,
#   "wcnv_min_InvTmp_ClWtrRet": 42.5,
#   "wcnv_min_HtSnkTmp": 53.0,
#   "wcnv_min_IGBTTmp": 0,
#   "wcnv_sdv_InvTmp_ClWtrFwd": 2.52428,
#   "wcnv_sdv_InvTmp_ClWtrRet": 1.72313,
#   "wcnv_sdv_HtSnkTmp": 1.30781,
#   "wcnv_sdv_IGBTTmp": 0,
#   "wmet_avg_MetAlt1_Hum": 0,
#   "wmet_avg_DewPTmp": 0,
#   "wmet_avg_MetAlt1_Press": 0,
#   "wmet_max_MetAlt1_Hum": 0,
#   "wmet_max_DewPTmp": 0,
#   "wmet_max_MetAlt1_Press": 0,
#   "wmet_min_MetAlt1_Hum": 0,
#   "wmet_min_DewPTmp": 0,
#   "wmet_min_MetAlt1_Press": 0,
#   "wmet_sdv_MetAlt1_Hum": 0,
#   "wmet_sdv_DewPTmp": 0,
#   "wmet_sdv_MetAlt1_Press": 0,
#   "alarm_id": 5132,
#   "alarm_desc": "Communication TEST",
#   "date_time_end": "2012-04-06 10:01:00",
#   "availability": 1,
#   "alarm_system": "Turbine"
# }
